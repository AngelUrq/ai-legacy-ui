# %% [markdown]
# # Document Analysis

# %%
# !apt-get install libpoppler-cpp-dev

# %pip install transformers
# %pip install clean-text
# %pip install openai
# %pip install pdftotext

# %%
# %cd /content/drive/MyDrive/Projects/ai-legacy
# Out:
# /content/drive/MyDrive/Projects/ai-legacy

# %%
import pandas as pd
import numpy as np
import re
import pdftotext

from transformers import pipeline

# %%
def read_pdf(path):
  pdf = pdftotext.PDF(open(path, 'rb'))

  return "".join(pdf)

text = read_pdf('papers/19900019299.pdf')
text
# Out:
# '                                                                                                   N90-28615\n                                 BLADE      TIP     RUBBING       STRESS       PREDICTION*\n               Gerald       A.     Brusher**,          Gary      A.    Davis,       and    Daniel       M.     Shea\n                           Rockwell         International/Rocketdyne                       Division\n                                             Canoga       Park,       California\n                                                           ABSTRACT\n      A   l_near       analysis         was     performed          to    determine         the     dynamic        response        of\na  turbine       blade       to    intermittent            rubbing         against       a   tip     seal.      The     response\nanalysis        consisted            of     a    parametric            study       where       the      rubbing         friction\nforce    was     assumed         to    vary     as   a   half     sine      wave     over      a   preselected           contact\narc.        The      length        of    the     contact         arc,      as    well      as    the     pump       speed,      was\nvaried      to determine              the    effects        of    each.        Results        show      that      for a given\ncontact       arc       there        are      distinct          critical          speeds         at    which         the     blade\nresponse       becomes         a   maximum.\n                                                       INTRODUCTION\n      Due    to    the     requirement            for    high     efficiency            in  modern         turbomachinery,\nclearances          between         turbine         blade      tips       and    the      turbine        housing         are    de-\nsired     to     be    as     small       as     is    practically            possible.             An    opposing         design\nrequirement           is    that       the    clearances            be     large      enough        to    prevent         rubbing\nof   the   blade       tips      on    the    housing        due     to    rotor      flexibility.               In   practice,\na  compromise          is    reached,         and    a   small       amount       of   rubbing         is    tolerated.         For\nexample,        in     the      Space       Shuttle         Main       Engine        (SSME)        high       pressure         fuel\nturbopump          (Fig.        i),      the     first-stage             turbine         blades        experience            light\nrubbing       over       approximately              20    to     30     degrees        of    arc.        To     minimize        tip\nrubbing      while        keeping         the    clearances            as    small      as    possible,           the     turbine\nis   mounted       eccentrically              in    the    pump      housing.          Under       steady-state            opera-\ntion,     sideloads          created         by    the    pumping         action       of   the      impellers         move     the\nrotor     to    the     centered          position         and     no     rubbing       occurs.           During       startup,\nhowever,        the      rotor      blades        contact         the     pump      housing         for     a   short      period\nof   time;     this       has     been     observed         in    the      turbine       hardware         during       posttest\ninspections           of    the      tip     seal     area.         A    typical        seal      segment         showing       the\nlight     rub    patterns          is   presented          in    Fig.      2.\n      The     purpose          of      the     analysis          presented           herein        was      to     assess       the\neffects       of     tip     rubbing        on     the    dynamic          response        ...

# %%
from cleantext import clean

def clean_text(text):
  return clean(text,
      fix_unicode=True,               # fix various unicode errors
      to_ascii=True,                  # transliterate to closest ASCII representation
      lower=True,                     # lowercase text
      no_line_breaks=True,           # fully strip line breaks as opposed to only normalizing them
      no_urls=False,                  # replace all URLs with a special token
      no_emails=False,                # replace all email addresses with a special token
      no_phone_numbers=False,         # replace all phone numbers with a special token
      no_numbers=False,               # replace all numbers with a special token
      no_digits=False,                # replace all digits with a special token
      no_currency_symbols=True,      # replace all currency symbols with a special token
      no_punct=True,                 # remove punctuations
      replace_with_punct="",          # instead of removing punctuations you may replace them
      replace_with_url="<URL>",
      replace_with_email="<EMAIL>",
      replace_with_phone_number="<PHONE>",
      replace_with_number="<NUMBER>",
      replace_with_digit="0",
      replace_with_currency_symbol="<CUR>",
      lang="en"                       # set to 'de' for German special handling
  )

text = clean_text(text)
text[:4000]
# Out:
# 'n9028615 blade tip rubbing stress prediction gerald a brusher gary a davis and daniel m shea rockwell internationalrocketdyne division canoga park california abstract a lnear analysis was performed to determine the dynamic response of a turbine blade to intermittent rubbing against a tip seal the response analysis consisted of a parametric study where the rubbing friction force was assumed to vary as a half sine wave over a preselected contact arc the length of the contact arc as well as the pump speed was varied to determine the effects of each results show that for a given contact arc there are distinct critical speeds at which the blade response becomes a maximum introduction due to the requirement for high efficiency in modern turbomachinery clearances between turbine blade tips and the turbine housing are de sired to be as small as is practically possible an opposing design requirement is that the clearances be large enough to prevent rubbing of the blade tips on the housing due to rotor flexibility in practice a compromise is reached and a small amount of rubbing is tolerated for example in the space shuttle main engine ssme high pressure fuel turbopump fig i the firststage turbine blades experience light rubbing over approximately 20 to 30 degrees of arc to minimize tip rubbing while keeping the clearances as small as possible the turbine is mounted eccentrically in the pump housing under steadystate opera tion sideloads created by the pumping action of the impellers move the rotor to the centered position and no rubbing occurs during startup however the rotor blades contact the pump housing for a short period of time this has been observed in the turbine hardware during posttest inspections of the tip seal area a typical seal segment showing the light rub patterns is presented in fig 2 the purpose of the analysis presented herein was to assess the effects of tip rubbing on the dynamic response of turbine blades in particular the turbine blades of the ssme high pressure fuel turbopump were analyzed as a representative case work reported herein was sponsored by nasamarshall space flight center under contract nas836361 presently attending the university of michigan 43 | fig i high pressure fuel turbopump fig 2 hpftp firststage tip seal segment analytical model to investigate the problem of rotation intermittent rubbing against a tip seal an analytical model was de i i i veloped that utilized a finite ele 3t load ment representation of the turbine blade the model fig 3 addressed a single blade fixed at the shank i lri 11i fj ji = root and free at the tip the boundary conditions at the root simulate the fixity of the blade due to the centrifugal loads acting through the firtree during high speed operation since the flexi bility of the disk actually admits motion of the blade shank the assumption of fixity results in slight increases in both natural frequencies and stresses however these effects are inconsequential in regard to understanding the dy fig 3 hpftp firststage turbine namic behavior of the blade due to blade finite element model to tip rubbing 44 to i>reslll the rotation of a rotor about an eccentric axis it wds asulled that the blade would be in contact with the tip seal over a jelldefined arc once per revolution only tangential frlctiorl effects were ft considered therefore a tangential load was applied to a lngle point on blade tip the amplitude of the forc fpeak ing fmct io ds set equal to the product of the normal load and the friction coefficient the friction coefficient was assumed to be con tru b =i= tfree stant however the normal load was trevolution 1 t assumed to vary as a hale sne wave over the duration of the rub fig half sine wave 4 this assumption was reasonable given the kinemat ics of rotation fig 4 friction force time about an eccentric axis history the model was designed to assess linear behavior only it was ini tially postulated that the blade would display stickslip behavior dur ing contact w ...

# %%
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer

def summarize(text):
  tokenizer = AutoTokenizer.from_pretrained("google/bigbird-pegasus-large-arxiv")

  model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-arxiv")

  inputs = tokenizer(text[:4000], return_tensors='pt')
  prediction = model.generate(**inputs)
  prediction = tokenizer.batch_decode(prediction)[0]
  prediction = prediction.replace('<s> ', '')
  prediction = prediction.replace('</s>', '..')

  return prediction.capitalize()

# %%
import os
import openai

def summarize(text):
  response = openai.Completion.create(
    engine="text-curie-001",
    prompt=f"Full text: {text[:4000]} Short summary:\n",
    temperature=0.3,
    max_tokens=100
  )

  return response.choices[0].text.replace('\n','')

summary = summarize(text)
summary
# Out:
# 'A lnear analysis was performed to determine the dynamic response of a turbine blade to intermittent rubbing against a tip seal. The response analysis consisted of a parametric study where the rubbing friction force was assumed to vary as a half sine wave over a preselected contact arc. The length of the contact arc as well as the pump speed was varied to determine the effects of each. Results show that for a given contact arc there are distinct critical speeds at which the blade response becomes a maximum. This is'

# %%
def get_keywords(text):
  response = openai.Completion.create(
    engine="text-davinci-002",
    prompt=f"Text: {text} List of 3 keywords, separated by comma:",
    temperature=0.3,
    max_tokens=50,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )

  output = response.choices[0].text.replace(',','\n')
  output = output.replace(')', '')
  output = re.sub('[0-9.]', '', output)
  output = output.splitlines()
  return [keyword.strip() for keyword in output if (keyword and len(keyword) < 30)]

get_keywords(summary)
# Out:
# ['system modeling', 'high speed bearings', 'cryogenics']

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

def summarize_one_line(text):
  model = AutoModelForSeq2SeqLM.from_pretrained("snrspeaks/t5-one-line-summary")
  tokenizer = AutoTokenizer.from_pretrained("snrspeaks/t5-one-line-summary")

  input_ids = tokenizer.encode("summarize: " + text[:1000], return_tensors="pt", add_special_tokens=True)
  
  generated_ids = model.generate(input_ids=input_ids,num_beams=5,max_length=50,repetition_penalty=2.5,length_penalty=1,early_stopping=True,num_return_sequences=3)
  preds = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]

  return preds[0]

summarize_one_line(text)
# Out:
# 'Some performance characteristics of divergent field bombardment thrusters by kaufman and vahrenkamp lewis research center cleveland ohio'

# %% [markdown]
# # Semantic Search

# %%
# !pip install sentence-transformers

# %%
import scipy
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-mpnet-base-v2')

# %% [markdown]
# # Paper Pipeline

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
# Out:
#    n                                              title           id  \
# 0  1                Blade Tip Rubbing Stress Prediction  19900019299
# 1  2  Evolution And Use Of Combined Mechanical And T...  19900019302
# 2  3  Adjustable Impedance, Force Feedback And Comma...  19900019691
# 3  7  A Hybrid Architecture For The Implementation O...  19900019716
# 4  4      Methods And Strategies Of Object Localization  19900019704
#
#               file     document type  \
# 0  19900019299.pdf  Conference Paper
# 1  19900019302.pdf  Conference Paper
# 2  19900019691.pdf  Conference Paper
# 3  19900019716.pdf  Conference Paper
# 4  19900019704.pdf  Conference Paper
#
#                                              authors      date acquired  \
# 0  Brusher, Gerald A. Davis, Gary A. Shea, Daniel M.  September 6, 2013
# 1       Cody, Joe C. Marty, David E. Moore, James D.  September 6, 2013
# 2  Sheridan, Thomas B. Raju, G. Jagganath. Buzan,...  September 6, 2013
# 3                  Koutsougeras, C. Papachristou, C.  September 6, 2013
# 4                      Shao, Lejun. Volz, Richard A.  September 6, 2013
#
#     publication date                        subject category  \
# 0  September 1, 1988           AIRCRAFT PROPULSION AND POWER
# 1  September 1, 1988                  MECHANICAL ENGINEERING
# 2   January 31, 1989  MAN/SYSTEM TECHNOLOGY AND LIFE SUPPORT
# 3   January 31, 1989                             CYBERNETICS
# 4   January 31, 1989  MAN/SYSTEM TECHNOLOGY AND LIFE SUPPORT
#
#                funding number
# 0  CONTRACT_GRANT: NAS8-36361
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
import json
import requests

papers = []

for index, row in df.iterrows():
  id = row['id']
  file = row['file']
  path = f'papers/{file}'

  pdf = read_pdf(path)
  text = clean_text(pdf)

  summary = summarize(text)
  keywords = get_keywords(summary)

  r = requests.get(f'https://ntrs.nasa.gov/api/citations/{id}')
  paper = r.json()
  paper['summary'] = summary
  paper['keywords'] = keywords

  print(summary)
  print(keywords)
  print('------------------')

  papers.append(paper)
# Out:
# The dynamic response of a turbine blade to intermittent rubbing against a tip seal was investigated using a parametric study. The response analysis consisted of a half-sine wave study where the rubbing friction force was assumed to vary as a half-sine wave over a preselected contact arc. The length of the contact arc and the pump speed were varied to determine the effects of each. Results show that for a given contact arc there are distinct critical speeds at which the blade response becomes a maximum. This
# ['turbine blade', 'intermittent rubbing', 'parametric study']
# ------------------
# The development of system modeling capabilities for high speed bearings operating in cryogenics supports the overall MSFCbearing and material development program which is designed to formulate and experimentally verify failure mechanisms and life prediction models for high speed bearing shaft systems operating in cryogenics. The modeling effort supports the BSMTProgram and the development and improvement of the SSME LO turbopumps. The operating characteristics of the SSME LO pump and bearing shaft characteristics are a complex task requiring the application of multidiscipl
# ['Bearing', 'Modeling', 'High speed']
# ------------------
# This paper summarizes four separate projects recently completed or in progress at the MIT ManMachine Systems Laboratory. These projects include: 1) development of a model of a remote manipulation system in which a human operator at the master port interacts with a task object at the slave port in a remote location; 2) design of feedback gains for the servomechanisms that transmit motion and force information from one port of the 2port to the other in both directions; 3) selection of stability requirements and specifications of desired
# ['remote manipulation', 'servomechanisms', 'stability requirements']
# ------------------
# This paper discusses the implementation of an earlier introduced neural net model for pattern classification, and considers data flow principles in the development of a machine that efficiently implements the model. Further enhancement with optical computing structures is also considered here.
# ['Neural net model', 'Pattern classification', 'Optical computing structures']
# ------------------
# This paper proposes a general object localization system structure discusses some important issues on localization and gives an overview of current available object localization algorithms and systems. The reviewed algorithms are characterized by their feature extracting matching strategies, range finding methods, the types of locatable objects, and the mathematical formulating methods.
# ['Object localization', 'Feature extraction', 'Matching']
# ------------------
# This paper presents a new scheme for the representation of objects in a 3D dynamic environment, which facilitates the rapid planning of collision-free paths. The scheme is based on a hierarchy of bounding spheres and rectangular sectors of spheres, which correspond to the faces of planar convex polyhedral objects. The path planning process uses an efficient generate-and-test philosophy, which exploits human 3D conceptual knowledge to propose and test heuristically satisfying collision-free paths. A satisfying path planner is
# ['Path planning', 'Collision avoidance', 'D object representation']
# ------------------
# An efficient adaptive neural learning paradigm for addressing the inverse kinematics of redundant manipulators is presented. The proposed methodology exploits the infinite local stability of terminal attractors, a new class of mathematical constructs which provide unique information processing capabilities to artificial neural systems for robotic applications. synaptic elements of such networks can rapidly acquire the kinematic invariances embedded within the presented samples. Jointspace configurations required to follow arbitrary endeffector trajectories can readily be computed in a significant departure from prior neuromorphic learning
# ['inverse kinematics', 'redundant manipulators', 'terminal attractors']
# ------------------
# A concept of nested hierarchical multiresolutional pyramidal information knowledge processing is introduced for a variety of systems including data and knowledge bases, vision control and manufacturing systems industrial automated robots and self-programmed autonomous intelligent machines. It is demonstrated in this paper that any intelligent module transforms sometimes irreversibly the knowledge it deals with, and this transformation affects the subsequent computation processes. Several types of knowledge transformation are reviewed, and conditions are analyzed which are required for organization and processing of redundant information knowledge in
# ['Knowledge transformation']
# ------------------
# This paper describes a method for locating the Mars Rover using an elevation map generated from Lite Data to provide greater detail from satellite data in exploring its environment. We will refer to the map generated from satellite data as the rover map and the map generated from local observations made by the rover as the local data. The rover map is then merged with the map generated from satellite data using the rover map centered elevation map. This technique requires that the rover be able to estimate its current location. The results of our
# ['+', '+ Mars Rover', '+ Satellite Data', '+ Local Observations']
# ------------------
# The paper discusses how to deal with the uncertainty in robot control programs, and how to create robust strategies. The first question is how to generate a fine motion strategy, which combines sensing operations with small robot movements. The second question is how to represent uncertainty and determine the points where a given manipulation program might fail.
# ['Robot control', 'uncertainty', 'robustness']
# ------------------
# A truly intelligent system that interacts with the physical world must be endowed with the ability to compute with shapes, despite this spatial reasoning being rarely regarded as part of mainstream AI. We argue that the study of intelligent spatial algorithms is a worthwhile activity, and give opinions and suggestions for the way forward. What is spatial reasoning? A truly intelligent system that interacts with the physical world must be endowed with the ability to compute with shapes, despite this the study of spatial reasoning is a young field and is often confused
# ['Spatial reasoning', 'Shape recognition', 'Object recognition']
# ------------------
# The operation and evaluation of a bioreactor designed for high intensity oxygen transfer in a microgravity environment is described. The reactor itself consists of a zero headspace liquid phase separated from the air supply by a long length of silicone rubber tubing through which the oxygen diffuses in and the carbon dioxide diffuses out. Mass transfer studies show that the oxygen is film diffusion controlled both externally and internally to the tubing and not by diffusion across the tube walls. Methods of upgrading the design to eliminate these resistances
# ['Bioreactor', 'Oxygen Transfer', 'Microgravity']
# ------------------
# The effects of microgravity on the body are complex and poorly understood. Some effects may be the result of passive microgravity influences, while others may be the result of reactive changes in the body's environment. It is difficult to determine which effects are the result of microgravity, and it is important to be aware of the many potential consequences of exposure to microgravity.
# ['microgravity', 'body', 'environment']
# ------------------
# The need for high rate oxygen transfer in microgravity for a cell-based environment presents a number of unique difficulties and challenges. The use of a phase-separated bioreactor appears to provide a way of overcoming these problems, resulting in a system capable of providing high cell densities with rapid fermentation rates. Some of the key design elements are discussed, including the biological processing and thus fermentation likely to take place in space under two main driving forces: firstly, as unique biological effects are uncovered
# ['Microgravity', 'Bioreactor', 'Fermentation']
# ------------------
# This technical paper is about the film boiling transition temperature for tissue cooled with liquid nitrogen. Robert Hendricks found that the film boiling transition temperature for tissue is around 260 degrees Celsius. This temperature is important because it is the temperature at which the tissue will start to boil. If the tissue boils, it will start to damage itself.Robert Hendricks also found that the tissue will freeze when microwave energy is used to revive it. The freezing temperature is around -196 degrees Celsius. This temperature is important because
# ['tissue', 'liquid nitrogen']
# ------------------
# This IBM Research report covers the period from May 26, 1970 to August 10, 1970. During this time, the boolean minimization algorithm was used to plan and program multipleoutput circuits. The goal of this work is to help design circuits with medium or large scale components.One of the subroutines developed for this purpose is a procedure for differentiating between failures in a logic circuit. This algorithm was presented in the Proceedings of the 1970 International Computer Group Conference.Another sub
# ['Boolean minimization', 'Multiple-output circuits']
# ------------------
# The present invention is a panel or envelope structure for use in space or other applications requiring a lightweight and compact reflector. The panel or envelope structure is made up of a plurality of inflatable cells each of which is capable of being inflated to a rigid configuration. The cells are separated by side walls which are provided with a plurality of apertures for fluid communication. The side walls are also provided with braces or supports to insure a rigid configuration when the structure is inflated. The panel or envelope structure
# ['Inflatable cells', 'Side walls', 'Braces or supports']
# ------------------
# This document contains predictions of the coronal and interplanetary magnetic fields. The predictions are based on models of the solar atmosphere and are limited by energy density. The effects of solar activity on coronal structure are also discussed.
# ['Solar atmosphere', 'Coronal structure', 'Solar activity']
# ------------------
# This document provides a certificate of correction to a patent that was originally filed in 1962. The patent is for a gas lubricant that minimizes corrosive wear. The certificate of correction states that the letters patent should read as "co-exected below columns 1 and 2, table 1 under the heading 'W for 190 read 5 0, same table under the heading 'M for 190 read 5 0 0."
# ['gas lubricant', 'corrosive wear', 'certificate of correction']
# ------------------
# The present invention relates to a trajectory correction propulsion system which is capable of multiple space starts and which employs an ignition weight small size reusability and suitably for varied start slug device sizes and classes of vehicles. The present invention also relates to a trajectory control propulsion system having feed launch errors thereby eliminating the need for the precise means for the propellant and catalyst which assure that launch instrumentation which is presently necessary for ignition will occur only when intended so as to eliminate most spacecraft flights in connection with trajectory
# ['Ignition weight', 'Reusability']
# ------------------
# The present invention is a nulltype vacuum microbalance which is capable of measuring minute static forces. The balance is free of moving parts and can be operated without calibration.
# ['vacuum microbalance', 'static force', 'calibration']
# ------------------
# This invention relates to a new and improved thermal energy responsive structure which can be used to change the direction of radiant waves.
# ['Thermal energy', 'Radiant waves', 'Directional change']
# ------------------
# The electricallyoperated rotary shutter of the invention is particularly well-suited for use on spacecrafts, and is particularly well-suited for controlling the aperture exposure time of a camera.
# ['spacecraft', 'camera', 'shutter']
# ------------------
# The invention is a thermoprotective device for balances, which includes a heat shield to protect the balance from high temperatures during tests.
# ['thermoprotective device', 'heat shield', 'balances']
# ------------------
# This technical note presents measurements of cross sections for np and na reactions induced by 145 mev neutrons in various isotopes of silicon. The experimentally determined values of activation cross sections are of 2132 + 183mb for silicon-28, 1125 f 168mb for silicon-29, and 155~q for silicon-30. These values are based on measurements of the monitor reaction. The key words suggested by the authors are "nuclear reactions," "compound nuclear model," "unclassified
# ['Nuclear reactions', 'Compound nuclear model', 'Unclassified', 'List of  keywords', 'separated by comma:', 'Nuclear reactions', 'Compound nuclear model', 'Unclassified']
# ------------------
# This document summarizes project activity during the period 1 January 1970 to 31 March 1970. Experimental work discussed includes the high resolution measurements of the 15 m band of co2 and the development of an ozone generating handling and measuring system. Theoretical analysis of the high resolution 15 m co2 data and of the 9 m 0 3 band are in progress. A literature survey on the distribution of co2 in the earths atmosphere is being made. Plans for continued work are being made.
# ['co', 'ozone', 'atmosphere']
# ------------------
# This paper examines the performance characteristics of divergentfield bombardment thrusters. It was found that maximum thruster utilization corresponds to only privileged regions near the magnetic field poles. The magnetic field is determined by the positions of the magnetic field poles and the softiron pole pieces. The performance of the thrusters was found to be independent of configuration changes.
# ['Magnetic field', 'Performance']
# ------------------
# This small university-funded effort was undertaken to demonstrate some of the useful information available in radar images observations on data gathered at Lawrence, Kansas with and without ground truth are presented. Changes of intensity and texture of fields when observed repeatedly can contribute to a history of field operations which would be significant in understanding the agricultural situation.
# ['Radar images', 'ground truth', 'agricultural situation']
# ------------------
# The psychological effects of living in a submarine are substantial for and appetizing submarine personnel menus. There is little to compare other than that in both the submarine and the space vehicle there are men confined who display the usual human trait of enjoying good food and being unhappy if their food is unpalatable. Navy ships are described as "taut ships," "ppy ships," and "goodfeeding ships." A happy ship is also a goodfeeding ship because as we all know food tastefully prepared and
# ['submarine', 'space', 'food']
# ------------------
# This document contains data which exceeds the sheet parameters. This document was reproduced from the best copy furnished by the organizational source. This document may contain toneontone or color graphs charts and/or pictures which have been reproduced in black and white. This document is paginated as submitted by the original source. Portions of this document are not fully legible due to the historical nature of some of the material. However, it is the best reproduction available from the original submission produced by the NASA Center for
# ['NASA', 'Space', 'Technology', 'List of  keywords', 'separated by comma:', 'NASA', 'Space', 'Technology']
# ------------------
# The invention is a self-erecting lightweight space structure made of flexible foam. It is resistant to micrometeroid damage, and can be manufactured cheaply without the need for royalties or inflation.
# ['Foam', 'space', 'structure']
# ------------------
# The National Aeronautics and Space Administration (NASA) is announcing that it has acquired two United States Patent Applications (USP's) covering a pivotal shock absorbing pad assembly. The USP's were filed on April 14, 1964, and September 28, 1965, by inventor Joseph F. Blumrich.The first USP covers a system design that has heretofore been of little concern to aerospace engineers. The second USP covers a shock absorbing pad assembly that is suitable
# ['shock absorbing pad assembly']
# ------------------
# This paper discusses the effects of surface roughness on heat transfer in converging and diverging nozzles. It was found that the heat transfer is not noticeably affected until the roughness height is greater than a given height, which seems to correspond to the approximated sublayer height. The effects of various degrees of surface roughness on heat transfer in two conical converging diverging nozzles with y+ nondimensional distance normal to the wall were studied. It was found that the heat
# ['surface roughness', 'heat transfer', 'converging diverging nozzles']
# ------------------
# The invention is an electrical discharge apparatus for forming metal parts. The apparatus includes a die block with a forming cavity, a bore communicating with the cavity, a blast head located above the die block and in contact with the forming cavity, and a holddown ring located adjacent the blast head. A chemical explosive is exploded under water, and shock waves are generated which are transmitted by the water against a metal blank. The explosive does not provide for rapid formation of the metal part, and is often hazardous to
# ['electrical discharge', 'metal parts', 'chemical explosive']
# ------------------
# This document discusses the various types of coatings that can be used on spacecraft, and how they are resistant to microbial attack.
# ['Coatings', 'Microbial attack', 'Spacecraft']
# ------------------
# This document is a brief about a shift register that eliminates logic gates and power switching circuits. This is a significant advantage because it reduces the weight and power requirements and power application to both portions of the register. Additionally, the register requires only two integrated circuits in operation, which makes it more reliable.
# ['shift register', 'logic gates', 'power switching circuits']
# ------------------
# This document discusses the effects of oxidation on intermediate moisture foods, and the use of metal chelating agents to prevent this.
# ['Oxidation', 'Intermediate moisture foods', 'Metal chelating agents']
# ------------------
# This document contains data which exceeds the sheet parameters it was furnished in this condition by the organizational source and is the best copy available. This document may contain toneontone or color graphs charts and/or pictures which have been reproduced in black and white. This document is paginated as submitted by the original source. Portions of this document are not fully legible due to the historical nature of some of the material, however it is the best reproduction available from the original submission produced by the NASA Center
# ['NASA', 'space', 'technology']
# ------------------
# This document is a NASA Tech Brief announcing a new technology derived from the US space program. The technology is designed to encourage commercial application.
# ['NASA', 'space program', 'technology']
# ------------------
# This document discusses a communications system designed to drive two 50 watt speakers underwater. The system was designed to switch between the speakers if needed, and to operate from a 12 volt power source.
# ['Communications system', 'Underwater', 'Speakers']
# ------------------
# This document discusses a digital decoding technique that can be used to convert phasedelay coded or modulated digital data to normal rz format. The technique has been tested in the laboratory and has been found to be accurate and reliable under severe noise conditions.
# ['digital decoding', 'phasedelay coding', 'modulated digital data']
# ------------------
# This brief describes a new technology that was derived from the US space program. The technology is designed to encourage commercial application. The brief provides information on how the technology works and the limitations of the technology.
# ['Space technology', 'commercial application', 'technology limitations']
# ------------------
# This brief discusses the results of investigations into the optimum doping range for photoemitters with a peak response at 9000 A. The data suggest that an optimum range exists between 8500 and 1018 cm3 for GaAs photoemitters. No patent action is contemplated by NASA, but the doping range for optimum response at a given wavelength is not necessarily in this range.
# ['Photoemitters', 'Doping', 'Wavelength']
# ------------------
# This document discusses the cast segment concept, which is a way to reduce the cost of rocket engines. The cast segment concept depends on the development of a thinwalled liner casting of the high technology alloy designated narloy. The cast segment concept was demonstrated to be good design suitability, good performance, and long life. There is no patent action contemplated by NASA. The state of the art was extended in the areas of source w r stud halter and h g diem of casting size
# ['Cast segment concept', 'Narloy', 'Halter']
# ------------------
# The new technology derived from the US space program is announced in a tech brief. This encourages commercial application of the technology. The tech brief is available on a subscription basis from the National Technical Information Service.
# ['space technology', 'commercial application']
# ------------------
# This document provides a brief description of a new technology that has been derived from the US space program. The technology is designed to encourage commercial application.
# ['Space technology', 'commercial application', 'technology transfer']
# ------------------
# This document discusses the advantages of using thin film resistors on chips instead of traditional metal oxide resistors. The resistors are less likely to be damaged by radiation and are therefore more reliable. They also save space on the chip.
# ['Thin film resistors', 'radiation', 'space']
# ------------------
# This document discusses the new technology derived from the US space program, which is aimed at encouraging commercial application. It provides information on the three main modes of operation for the propellant-constrained minimum time orbit transfer program, as well as on the relationship between the trajectories involved.
# ['US space program', 'commercial application']
# ------------------
# This document discusses the technology behind the Mate system, which is used to compile and execute machine instructions for space systems. The Mate system also performs data management and bookkeeping services.
# ['Mate system', 'machine instructions', 'data management']
# ------------------
# This document discusses the treatment of blueberries prior to freeze dehydration. It notes that freeze dried blueberries and several other fruits have tough chewy skins upon rehydration, which detracts from their palatability. No additional documentation is available on the subject. Questions regarding the technology may be directed to the technology utilization officer at the manned spacecraft center.
# ['blueberries', 'freeze dehydration', 'chewy skins']
# ------------------

# %%
summaries = []

for paper in papers:
  summary = paper['summary']
  summaries.append(summary)

embeddings = model.encode(summaries)
embeddings.shape
# Out:
# (50, 768)

# %%
for i in range(len(embeddings)):
  distances = []

  for j in range(len(embeddings)):
    if i == j:
      continue

    distance = scipy.spatial.distance.cdist([embeddings[i, :]], [embeddings[j, :]], "cosine")[0]

    distances.append({
        'id': papers[j]['id'],
        'score': float(distance)
    })

  papers[i]['scores'] = distances
  papers[i]['embedding'] = list(embeddings[i, :].astype(float))

# %%
data = {}
data['documents'] = papers

with open('data.json', 'w') as f:
  json.dump(data, f)

# %%
for i in range(3):
  for j in range(3):
    distance = scipy.spatial.distance.cdist([embeddings[i, :]], [embeddings[j, :]], "cosine")[0]
    
    print(f'{i + 1} {j + 1} - {distance}')
# Out:
# 1 1 - [0.]
# 1 2 - [0.6003964]
# 1 3 - [0.74647799]
# 2 1 - [0.6003964]
# 2 2 - [1.11022302e-16]
# 2 3 - [0.78185406]
# 3 1 - [0.74647799]
# 3 2 - [0.78185406]
# 3 3 - [0.]

# %% [markdown]
# # Find xyz coordinates for every node using autodiff

# %%
start = 1
distances = []

for i in range(50):
  for j in range(start, 50):
    distance = scipy.spatial.distance.cdist([embeddings[i, :]], [embeddings[j, :]], "cosine")[0]
    distances.append(float(distance))

    print(f'{i + 1} {j + 1} - {distance}')

  start += 1

# %%
import tensorflow as tf

tensors = []

for i in range(50):
  tensors.append(tf.Variable(tf.random.uniform([3],minval=0), dtype=tf.float32))

y = tf.constant(distances)

tensors

# %%
learning_rate = 1.0

for epoch in range(500):
  start = 1

  with tf.GradientTape() as tape:
    distances = []

    for i in range(len(tensors)):
      for j in range(start, len(tensors)):
        distance = tf.sqrt(tf.reduce_sum(tf.square(tensors[i] - tensors[j])))
        distances.append(distance)

      start += 1

    loss = tf.reduce_mean(tf.square(distances - y))

    if epoch % 10 == 0:
      print(loss)

  grads = tape.gradient(loss, tensors)

  for i in range(len(grads)):
    tensors[i].assign(tensors[i] - grads[i] * learning_rate)

# %%
distances = []
start = 1

for i in range(len(tensors)):
  for j in range(start, len(tensors)):
    distance = tf.sqrt(tf.reduce_sum(tf.square(tensors[i] - tensors[j])))
    distances.append(distance)

  start += 1

# %%
for i in range(len(distances)):
  print(distances[i])
  print(y[i])
  print()

# %%
for tensor in tensors:
  print(tensor.numpy())
# Out:
# [ 0.12492618 -0.06804582  0.27753368]
# [ 0.3583211  -0.08433492  0.6218014 ]
# [0.0252158  0.3560477  0.38003358]
# [-0.18174738  0.4888676   0.4195969 ]
# [-0.03924221  0.95302296  0.69959134]
# [0.06036701 1.007531   0.42333362]
# [-0.12252923  0.52279544  0.16437641]
# [-0.06368641  0.7791059   0.24993457]
# [0.2125518 1.0553161 0.7984142]
# [-0.10103215  0.7381484   0.57547957]
# [0.05990313 1.0872567  0.28969258]
# [0.9417694  0.22285506 0.38283026]
# [1.1053083 0.5048518 0.2631152]
# [1.0631696  0.27855793 0.42589557]
# [0.7314057  0.01719058 0.11060737]
# [-0.12866162  0.38519153  0.7248101 ]
# [0.5548065 1.0224268 0.2884577]
# [0.8503242  0.8424246  0.99853265]
# [ 0.58372027  0.35632268 -0.01998488]
# [0.56519276 1.0783802  0.54172343]
# [0.80024713 0.82034105 0.09542564]
# [ 0.41463062  0.6879742  -0.04854409]
# [0.7122417  0.976044   0.47170034]
# [ 0.6923146  0.5903559 -0.0455824]
# [ 0.56624967 -0.02770462  0.96538556]
# [0.8088235  0.49161625 1.0100676 ]
# [0.35371205 0.20468804 0.96426797]
# [0.44893855 1.0142657  1.0251031 ]
# [1.0785555  0.75355095 0.3649115 ]
# [0.8510746  0.59922534 0.7676195 ]
# [0.54363596 0.89107466 0.16835831]
# [0.5456063  0.42481846 0.31612954]
# [ 0.37481287 -0.02882636  0.08091451]
# [ 0.37324437  0.8982472  -0.02118985]
# [0.797838   0.05974494 0.5796683 ]
# [-0.00749026  0.38991883  0.8831891 ]
# [ 0.8248577  -0.10768996  0.33308303]
# [0.8519172 0.6147502 0.7678001]
# [0.5270675  0.69302654 0.5933734 ]
# [0.2121831  0.339369   0.03281541]
# [0.17242971 0.6389235  1.1272993 ]
# [0.55960053 0.7049661  0.5927599 ]
# [0.5369227  0.30262417 1.1805872 ]
# [0.3455162  0.02732011 0.43449017]
# [0.49488604 0.60272676 0.6559519 ]
# [0.55125445 0.6762575  0.5856328 ]
# [0.12964593 0.08447625 0.7912616 ]
# [0.5349749 0.5541034 0.8217212]
# [0.28013188 0.615999   0.8356977 ]
# [0.9823416 0.2365897 0.6947558]
